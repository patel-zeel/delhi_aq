# %% [markdown]
# # Exploration

# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
data = xr.open_dataset("../data/delhi_cpcb_2022.nc")
data
# Out:
# <xarray.Dataset>
# Dimensions:    (station: 40, time: 8783)
# Coordinates:
#   * station    (station) object 'Alipur, Delhi - DPCC' ... 'Wazirpur, Delhi -...
#   * time       (time) datetime64[ns] 2022-01-01T00:30:00 ... 2023-01-01T22:23:30
#     latitude   (station) float64 ...
#     longitude  (station) float64 ...
# Data variables: (12/21)
#     From Date  (station, time) datetime64[ns] ...
#     To Date    (station, time) datetime64[ns] ...
#     PM2.5      (station, time) float64 ...
#     PM10       (station, time) float64 ...
#     NO         (station, time) float64 ...
#     NO2        (station, time) float64 ...
#     ...         ...
#     WD         (station, time) float64 ...
#     SR         (station, time) float64 ...
#     BP         (station, time) float64 ...
#     AT         (station, time) float64 ...
#     RF         (station, time) float64 ...
#     TOT-RF     (station, time) float64 ...

# %%
df = data.to_dataframe().reset_index().set_index("time")
df = df.loc["2022"]

# %%
df.columns
# Out:
# Index(['station', 'From Date', 'To Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx',
#        'NH3', 'SO2', 'CO', 'Ozone', 'Benzene', 'Toluene', 'RH', 'WS', 'WD',
#        'SR', 'BP', 'AT', 'RF', 'TOT-RF', 'latitude', 'longitude'],
#       dtype='object')

# %%
df = df.rename(columns={"RH": "relative_humidity", "WS": "wind_speed", "WD": "wind_direction", "SR": "solar_radiation", "BP": "pressure", "AT": "temperature", "RF": "rain_fall", "TOT-RF": "total_rainfall"})
df.columns
# Out:
# Index(['station', 'From Date', 'To Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx',
#        'NH3', 'SO2', 'CO', 'Ozone', 'Benzene', 'Toluene', 'relative_humidity',
#        'wind_speed', 'wind_direction', 'solar_radiation', 'pressure',
#        'temperature', 'rain_fall', 'total_rainfall', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### Stations

# %%
df.station.unique().tolist()
# Out:
# ['Alipur, Delhi - DPCC',
#  'Anand Vihar, Delhi - DPCC',
#  'Ashok Vihar, Delhi - DPCC',
#  'Aya Nagar, Delhi - IMD',
#  'Bawana, Delhi - DPCC',
#  'Burari Crossing, Delhi - IMD',
#  'CRRI Mathura Road, Delhi - IMD',
#  'Chandni Chowk, Delhi - IITM',
#  'DTU, Delhi - CPCB',
#  'Dr. Karni Singh Shooting Range, Delhi - DPCC',
#  'Dwarka-Sector 8, Delhi - DPCC ',
#  'East Arjun Nagar, Delhi - CPCB',
#  'IGI Airport (T3), Delhi - IMD',
#  'IHBAS, Dilshad Garden, Delhi - CPCB',
#  'ITO, Delhi - CPCB',
#  'Jahangirpuri, Delhi - DPCC',
#  'Jawaharlal Nehru Stadium, Delhi - DPCC',
#  'Lodhi Road, Delhi - IITM',
#  'Lodhi Road, Delhi - IMD',
#  'Major Dhyan Chand National Stadium, Delhi - DPCC',
#  'Mandir Marg, Delhi - DPCC',
#  'Mundka, Delhi - DPCC',
#  'NSIT Dwarka, Delhi - CPCB',
#  'Najafgarh, Delhi - DPCC',
#  'Narela, Delhi - DPCC',
#  'Nehru Nagar, Delhi - DPCC',
#  'North Campus, DU, Delhi - IMD',
#  'Okhla Phase-2, Delhi - DPCC',
#  'Patparganj, Delhi - DPCC',
#  'Punjabi Bagh, Delhi - DPCC',
#  'Pusa, Delhi - DPCC',
#  'Pusa, Delhi - IMD',
#  'R K Puram, Delhi - DPCC',
#  'Rohini, Delhi - DPCC',
#  'Shadipur, Delhi - CPCB',
#  'Sirifort, Delhi - CPCB',
#  'Sonia Vihar, Delhi - DPCC',
#  'Sri Aurobindo Marg, Delhi - DPCC',
#  'Vivek Vihar, Delhi - DPCC',
#  'Wazirpur, Delhi - DPCC']

# %% [markdown]
# ### Number of stations

# %%
df.station.unique().size
# Out:
# 40

# %% [markdown]
# ### Number of measurements per station

# %%
num_points_per_station = df.station.value_counts()[0]
assert num_points_per_station == 24 * 365  # hourly data for a year

# %% [markdown]
# ### Fraction of valid PM2.5 measurements per station

# %%
fraction_of_pm25_data = df.dropna(subset="PM2.5").station.value_counts()/num_points_per_station
fraction_of_pm25_data.plot(kind="bar", figsize=(20, 5), grid=True, yticks=np.arange(0, 1.1, 0.1));

# %%
fraction_of_pm25_data.index[-5:].tolist()
# Out:
# ['IHBAS, Dilshad Garden, Delhi - CPCB',
#  'DTU, Delhi - CPCB',
#  'Burari Crossing, Delhi - IMD',
#  'Chandni Chowk, Delhi - IITM',
#  'Lodhi Road, Delhi - IITM']

# %% [markdown]
# ### Fraction of valid meteorological + PM2.5 measurements per station

# %%
fraction_of_met_data = df.dropna(subset=["PM2.5", 'relative_humidity',
       'wind_speed', 'wind_direction', 'solar_radiation', 'pressure',
       'temperature', 'rain_fall', 'total_rainfall']).station.value_counts()/num_points_per_station
fraction_of_pm25_data.plot(kind="bar", figsize=(20, 5), grid=True, yticks=np.arange(0, 1.1, 0.1));

# %% [markdown]
# ### Plot PM2.5 v/s a meteorological feature time-series for a random station

# %%
np.random.seed(2)
station = np.random.choice(df.station.unique())
station_df = df[df.station == station]

fig, ax = plt.subplots(figsize=(20, 5))
station_df["pressure"].plot(figsize=(20, 5), grid=True, ax=ax);
twin_ax = ax.twinx()
station_df["relative_humidity"].plot(figsize=(20, 5), grid=True, ax=twin_ax, color="red", alpha=0.5);
ax.set_title(station);
ax.legend();
twin_ax.legend();

# %%
station_df[["PM2.5", 'relative_humidity',
       'wind_speed', 'wind_direction', 'solar_radiation', 'pressure',
       'temperature']].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b1ae0_row0_col0, #T_b1ae0_row1_col1, #T_b1ae0_row2_col2, #T_b1ae0_row3_col3, #T_b1ae0_row4_col4, #T_b1ae0_row5_col5, #T_b1ae0_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b1ae0_row0_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_b1ae0_row0_col2, #T_b1ae0_row1_col3, #T_b1ae0_row1_col4, #T_b1ae0_row5_col6, #T_b1ae0_row6_col0, #T_b1ae0_row6_col1, #T_b1ae0_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b1ae0_row0_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b1ae0_row0_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b1ae0_row0_col5 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_b1ae0_row0_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b1ae0_row1_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_b1ae0_row1_col2, #T_b1ae0_row2_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b1ae0_row1_col5, #T_b1ae0_row2_col6 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_b1ae0_row1_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b1ae0_row2_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b1ae0_row2_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b1ae0_row2_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_b1ae0_row2_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b1ae0_row3_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_b1ae0_row3_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b1ae0_row3_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b1ae0_row3_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_b1ae0_row3_col5 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b1ae0_row3_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_b1ae0_row4_col0, #T_b1ae0_row5_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b1ae0_row4_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b1ae0_row4_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_b1ae0_row4_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b1ae0_row4_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b1ae0_row4_col6 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_b1ae0_row5_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_b1ae0_row5_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_b1ae0_row5_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b1ae0_row5_col3 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b1ae0_row6_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_b1ae0_row6_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b1ae0_row6_col4 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# </style>
# <table id="T_b1ae0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1ae0_level0_col0" class="col_heading level0 col0" >PM2.5</th>
#       <th id="T_b1ae0_level0_col1" class="col_heading level0 col1" >relative_humidity</th>
#       <th id="T_b1ae0_level0_col2" class="col_heading level0 col2" >wind_speed</th>
#       <th id="T_b1ae0_level0_col3" class="col_heading level0 col3" >wind_direction</th>
#       <th id="T_b1ae0_level0_col4" class="col_heading level0 col4" >solar_radiation</th>
#       <th id="T_b1ae0_level0_col5" class="col_heading level0 col5" >pressure</th>
#       <th id="T_b1ae0_level0_col6" class="col_heading level0 col6" >temperature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1ae0_level0_row0" class="row_heading level0 row0" >PM2.5</th>
#       <td id="T_b1ae0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b1ae0_row0_col1" class="data row0 col1" >0.228034</td>
#       <td id="T_b1ae0_row0_col2" class="data row0 col2" >-0.389168</td>
#       <td id="T_b1ae0_row0_col3" class="data row0 col3" >-0.060458</td>
#       <td id="T_b1ae0_row0_col4" class="data row0 col4" >-0.264521</td>
#       <td id="T_b1ae0_row0_col5" class="data row0 col5" >0.570978</td>
#       <td id="T_b1ae0_row0_col6" class="data row0 col6" >-0.532048</td>
#     </tr>
#     <tr>
#       <th id="T_b1ae0_level0_row1" class="row_heading level0 row1" >relative_humidity</th>
#       <td id="T_b1ae0_row1_col0" class="data row1 col0" >0.228034</td>
#       <td id="T_b1ae0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b1ae0_row1_col2" class="data row1 col2" >-0.156962</td>
#       <td id="T_b1ae0_row1_col3" class="data row1 col3" >-0.207520</td>
#       <td id="T_b1ae0_row1_col4" class="data row1 col4" >-0.434518</td>
#       <td id="T_b1ae0_row1_col5" class="data row1 col5" >0.307618</td>
#       <td id="T_b1ae0_row1_col6" class="data row1 col6" >-0.608594</td>
#     </tr>
#     <tr>
#       <th id="T_b1ae0_level0_row2" class="row_heading level0 row2" >wind_speed</th>
#       <td id="T_b1ae0_row2_col0" class="data row2 col0" >-0.389168</td>
#       <td id="T_b1ae0_row2_col1" class="data row2 col1" >-0.156962</td>
#       <td id="T_b1ae0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b1ae0_row2_col3" class="data row2 col3" >-0.006016</td>
#       <td id="T_b1ae0_row2_col4" class="data row2 col4" >0.355926</td>
#       <td id="T_b1ae0_row2_col5" class="data row2 col5" >-0.333636</td>
#       <td id="T_b1ae0_row2_col6" class="data row2 col6" >0.306206</td>
#     </tr>
#     <tr>
#       <th id="T_b1ae0_level0_row3" class="row_heading level0 row3" >wind_direction</th>
#       <td id="T_b1ae0_row3_col0" class="data row3 col0" >-0.060458</td>
#       <td id="T_b1ae0_row3_col1" class="data row3 col1" >-0.207520</td>
#       <td id="T_b1ae0_row3_col2" class="data row3 col2" >-0.006016</td>
#       <td id="T_b1ae0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b1ae0_row3_col4" class="data row3 col4" >0.117522</td>
#       <td id="T_b1ae0_row3_col5" class="data row3 col5" >0.057706</td>
#       <td id="T_b1ae0_row3_col6" class="data row3 col6" >0.040303</td>
#     </tr>
#     <tr>
#       <th id="T_b1ae0_level0_row4" class="row_heading level0 row4" >solar_radiation</th>
#       <td id="T_b1ae0_row4_col0" class="data row4 col0" >-0.264521</td>
#       <td id="T_b1ae0_row4_col1" class="data row4 col1" >-0.434518</td>
#       <td id="T_b1ae0_row4_col2" class="data row4 col2" >0.355926</td>
#       <td id="T_b1ae0_row4_col3" class="data row4 col3" >0.117522</td>
#       <td id="T_b1ae0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b1ae0_row4_col5" class="data row4 col5" >-0.184968</td>
#       <td id="T_b1ae0_row4_col6" class="data row4 col6" >0.439358</td>
#     </tr>
#     <tr>
#       <th id="T_b1ae0_level0_row5" class="row_heading level0 row5" >pressure</th>
#       <td id="T_b1ae0_row5_col0" class="data row5 col0" >0.570978</td>
#       <td id="T_b1ae0_row5_col1" class="data row5 col1" >0.307618</td>
#       <td id="T_b1ae0_row5_col2" class="data row5 col2" >-0.333636</td>
#       <td id="T_b1ae0_row5_col3" class="data row5 col3" >0.057706</td>
#       <td id="T_b1ae0_row5_col4" class="data row5 col4" >-0.184968</td>
#       <td id="T_b1ae0_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_b1ae0_row5_col6" class="data row5 col6" >-0.779530</td>
#     </tr>
#     <tr>
#       <th id="T_b1ae0_level0_row6" class="row_heading level0 row6" >temperature</th>
#       <td id="T_b1ae0_row6_col0" class="data row6 col0" >-0.532048</td>
#       <td id="T_b1ae0_row6_col1" class="data row6 col1" >-0.608594</td>
#       <td id="T_b1ae0_row6_col2" class="data row6 col2" >0.306206</td>
#       <td id="T_b1ae0_row6_col3" class="data row6 col3" >0.040303</td>
#       <td id="T_b1ae0_row6_col4" class="data row6 col4" >0.439358</td>
#       <td id="T_b1ae0_row6_col5" class="data row6 col5" >-0.779530</td>
#       <td id="T_b1ae0_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
